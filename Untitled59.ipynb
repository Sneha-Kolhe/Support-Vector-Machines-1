# %% [markdown]
# ## Q1. What is the mathematical formula for a linear SVM?

# %%
The mathematical formulation of a linear Support Vector Machine (SVM) is based on the concept of finding a hyperplane that best separates the classes in the feature space. Here's the mathematical formulation of a linear SVM:

Given a training dataset with 
�
n samples 
{
(
�
(
1
)
,
�
(
1
)
)
,
(
�
(
2
)
,
�
(
2
)
)
,
.
.
.
,
(
�
(
�
)
,
�
(
�
)
)
}
{(x 
(1)
 ,y 
(1)
 ),(x 
(2)
 ,y 
(2)
 ),...,(x 
(n)
 ,y 
(n)
 )}, where 
�
(
�
)
x 
(i)
  represents the feature vector of the 
�
ith sample, 
�
(
�
)
y 
(i)
  represents the corresponding class label (either -1 or 1 for binary classification), and 
�
(
�
)
∈
�
�
x 
(i)
 ∈R 
d
  is a 
�
d-dimensional feature vector.

The goal of a linear SVM is to find the optimal hyperplane that maximally separates the classes. Mathematically, the decision function of a linear SVM can be represented as:

�
(
�
)
=
sign
(
�
�
�
+
�
)
f(x)=sign(w 
T
 x+b)

Where:

�
w is the weight vector (normal to the hyperplane).
�
x is the feature vector of the input sample.
�
b is the bias term (intercept).
sign
(
⋅
)
sign(⋅) is the sign function, which assigns a class label based on the sign of its argument.
The optimal hyperplane is found by solving the following optimization problem:

minimize
1
2
∥
�
∥
2
minimize 
2
1
​
 ∥w∥ 
2
 

Subject to the constraints:

�
(
�
)
(
�
�
�
(
�
)
+
�
)
≥
1
for all 
�
=
1
,
2
,
.
.
.
,
�
y 
(i)
 (w 
T
 x 
(i)
 +b)≥1for all i=1,2,...,n

This formulation aims to maximize the margin between the classes while ensuring that all samples are correctly classified or lie on the correct side of the decision boundary.

The Lagrange dual of the optimization problem is typically solved, leading to the formulation in terms of Lagrange multipliers 
�
�
α 
i
​
 . The final decision function for prediction is based on the support vectors, which are the samples that lie on the margin or violate the margin.
